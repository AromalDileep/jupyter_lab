# %%
# import numpy as np
# import pandas as pd
# from sklearn.datasets import make_blobs
# from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
# from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# # Generate a synthetic dataset
# X, _ = make_blobs(n_samples=1000, centers=4, cluster_std=1.0, random_state=42)

# # Define clustering algorithms
# clustering_algorithms = {
#     "K-Means": KMeans(n_clusters=4, random_state=42),
#     "DBSCAN": DBSCAN(eps=0.5, min_samples=5),
#     "Agglomerative Clustering": AgglomerativeClustering(n_clusters=4)
# }

# # DataFrame to store evaluation results
# results = pd.DataFrame(columns=["Algorithm", "Silhouette Score", "Davies-Bouldin Index", "Calinski-Harabasz Index"])

# # Evaluate each algorithm
# for name, algorithm in clustering_algorithms.items():
#     model = algorithm.fit(X)
#     labels = model.labels_ if hasattr(model, "labels_") else model.predict(X)
    
#     # Ignore algorithms that label all points as noise
#     if len(np.unique(labels)) > 1:
#         silhouette = silhouette_score(X, labels)
#         davies_bouldin = davies_bouldin_score(X, labels)
#         calinski_harabasz = calinski_harabasz_score(X, labels)
#     else:
#         silhouette, davies_bouldin, calinski_harabasz = np.nan, np.nan, np.nan
    
#     results = results.append({
#         "Algorithm": name,
#         "Silhouette Score": silhouette,
#         "Davies-Bouldin Index": davies_bouldin,
#         "Calinski-Harabasz Index": calinski_harabasz
#     }, ignore_index=True)

# # Sort results by Silhouette Score (higher is better)
# results = results.sort_values(by="Silhouette Score", ascending=False)

# # Display results
# print(results)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Generate a synthetic dataset
X, _ = make_blobs(n_samples=1000, centers=4, cluster_std=1.0, random_state=42)

# Define clustering algorithms
clustering_algorithms = {
    "K-Means": KMeans(n_clusters=4, random_state=42),
    "DBSCAN": DBSCAN(eps=0.5, min_samples=5),
    "Agglomerative Clustering": AgglomerativeClustering(n_clusters=4)
}

# List to store evaluation results
results = []

# Evaluate each algorithm
for name, algorithm in clustering_algorithms.items():
    model = algorithm.fit(X)
    labels = model.labels_ if hasattr(model, "labels_") else model.predict(X)
    
    # Ignore algorithms that label all points as noise
    if len(np.unique(labels)) > 1:
        silhouette = silhouette_score(X, labels)
        davies_bouldin = davies_bouldin_score(X, labels)
        calinski_harabasz = calinski_harabasz_score(X, labels)
    else:
        silhouette, davies_bouldin, calinski_harabasz = np.nan, np.nan, np.nan
    
    results.append({
        "Algorithm": name,
        "Silhouette Score": silhouette,
        "Davies-Bouldin Index": davies_bouldin,
        "Calinski-Harabasz Index": calinski_harabasz
    })

# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Sort results by Silhouette Score (higher is better)
results_df = results_df.sort_values(by="Silhouette Score", ascending=False)

# Display results
results_df
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
#                   Algorithm  Silhouette Score  Davies-Bouldin Index  \
# 0                   K-Means          0.791598              0.292330
# 2  Agglomerative Clustering          0.791598              0.292330
# 1                    DBSCAN          0.497161              1.288477
#
#    Calinski-Harabasz Index
# 0             11066.971284
# 2             11066.971284
# 1              2012.072392
