# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 

df = pd.read_csv('/home/aromal/Documents/jupyter_Lab/Datasets_Main/Linear_regression/placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Placement(in LPA)')
# Out:
# Text(0, 0.5, 'Placement(in LPA)')

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test.iloc[0].values.reshape(-1,1))
# Out:
# /home/aromal/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_test, model.predict(X_test), color ='r')
plt.xlabel('CGPA')
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')
